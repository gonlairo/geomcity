# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/rodrigo/Documents/jg/data/spain/aemet_complete.csv')

# %%
df.head()
# Out:
#         fecha  provincia indicativo       nombre  tmed  tmin  tmax  prec  \
# 0  1968-03-01  TARRAGONA      0002I  VANDELLÒS     8.9   6.6  11.2  21,0
# 1  1968-03-02  TARRAGONA      0002I  VANDELLÒS    10.9   6.0  15.8   0,0
# 2  1968-03-03  TARRAGONA      0002I  VANDELLÒS     NaN   NaN   NaN   0,0
# 3  1968-03-04  TARRAGONA      0002I  VANDELLÒS    10.9   7.8  14.0   6,5
# 4  1968-03-05  TARRAGONA      0002I  VANDELLÒS     NaN   NaN   NaN   0,0
#
#    altitud horatmin horatmax
# 0       32    03:00    18:00
# 1       32    07:10    15:00
# 2       32      NaN      NaN
# 3       32    05:00    11:40
# 4       32      NaN      NaN

# %%
uniqueids = np.unique(list(df['nombre']))
uniqueids
# Out:
# array(['A CORUÑA', 'A CORUÑA AEROPUERTO', 'A POBRA DE TRIVES', 'ABLA',
#        'ADRA', 'ALAJAR', 'ALBACETE', 'ALBACETE BASE AÉREA', 'ALBORÁN',
#        'ALCANTARILLA, BASE AÉREA', 'ALCAÑIZ', 'ALICANTE-ELCHE AEROPUERTO',
#        'ALICANTE/ALACANT', 'ALMERÍA', 'ALMERÍA AEROPUERTO', 'ANDÚJAR',
#        'ANTEQUERA', 'ARAGÜÉS DEL PUERTO', 'ARANDA DE DUERO',
#        'ARANGUREN, ILUNDAIN  ', 'ARANJUEZ', 'ARENYS DE MAR',
#        'ARROYO DEL OJANCO', 'ASTURIAS AEROPUERTO', 'AUTILLA DEL PINO',
#        'AYAMONTE', 'BADAJOZ AEROPUERTO', 'BARCELONA',
#        'BARCELONA AEROPUERTO', 'BARCELONA, FABRA',
#        'BARDENAS REALES, BASE AÉREA ', 'BAZA', 'BAZTAN, IRURITA ',
#        'BELORADO', 'BENAVENTE', 'BIELSA', 'BILBAO AEROPUERTO',
#        'BUITRAGO DEL LOZOYA', 'BUJARALOZ', 'BURGOS AEROPUERTO',
#        'CABO BUSTO', 'CABO PEÑAS', 'CABO VILAN', 'CADREITA', 'CALAMOCHA',
#        'CALAMOCHA, AERÓDROMO', 'CALANDA', 'CALATAYUD', 'CAPDEPERA',
# ...

# %%
len(uniqueids)
# Out:
# 288
